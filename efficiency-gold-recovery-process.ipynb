# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Проверка-эффективности-обогащения" data-toc-modified-id="Проверка-эффективности-обогащения-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Проверка эффективности обогащения</a></span></li><li><span><a href="#Различие-тестовой-и-обучающей-выборок" data-toc-modified-id="Различие-тестовой-и-обучающей-выборок-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Различие тестовой и обучающей выборок</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Концентрации-металлов-Au,-Ag,-Pb-на-различных-этапах-технологического-процесса" data-toc-modified-id="Концентрации-металлов-Au,-Ag,-Pb-на-различных-этапах-технологического-процесса-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Концентрации металлов Au, Ag, Pb на различных этапах технологического процесса</a></span></li><li><span><a href="#Распределение-гранул-сырья-в-обучающей-и-тестовой-выборках" data-toc-modified-id="Распределение-гранул-сырья-в-обучающей-и-тестовой-выборках-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Распределение гранул сырья в обучающей и тестовой выборках</a></span></li><li><span><a href="#Суммарная-концентрация-всех-веществ-на-разных-стадиях" data-toc-modified-id="Суммарная-концентрация-всех-веществ-на-разных-стадиях-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Суммарная концентрация всех веществ на разных стадиях</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Удаление-аномальных-значений,-выделение-обучающей-и-тестовой-выборок" data-toc-modified-id="Удаление-аномальных-значений,-выделение-обучающей-и-тестовой-выборок-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Удаление аномальных значений, выделение обучающей и тестовой выборок</a></span></li><li><span><a href="#Метрики-качества-моделей" data-toc-modified-id="Метрики-качества-моделей-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Метрики качества моделей</a></span></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Обучение моделей</a></span></li><li><span><a href="#Сравнение-с-DummyRegressor" data-toc-modified-id="Сравнение-с-DummyRegressor-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Сравнение с DummyRegressor</a></span></li></ul></li><li><span><a href="#Вывод-по-проекту" data-toc-modified-id="Вывод-по-проекту-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Вывод по проекту</a></span></li></ul></div>

# %% [markdown]
# # Описание проекта

# %% [markdown]
# В данном проекте нам необходимо построить модель, которая сможет предсказывать эффективность процесса восстановления золота из руды.
#
# Технологический процесс происходит поэтапно:
# 1. Методом пенной флотации из золотосодержащей руды (пыли) выделяются концентраты с ценными металлами. Данный метод основан на способности пузырьков газа плотно прилипать к гидрофобным (отталкивающим воду) частичкам горной породы. При этом плотность частички с прилипшими пузырьками оказывается меньше, чем плотность жидкой среды и частичка всплывает (флотирует) вверх. Таким образом образуется верхний слой частичек породы, который в дальнейшем собирается или удаляется.
# * На данном этапе в флотационную установку подается смесь, содержащая ценные металлы: золото, свинец, серебро; добавляются флотационные реагенты, ксантогенаты, сульфаты и силикаты, сам процесс так же регулируется подачей воздуха (пузырьков) и прочими параметрами. Получается много переменных, которые влияют на эффективность флотации.
# 2. В результате смесь разделяется на черновой концетрат металлов и отвальные хвосты (которые удаляют). Черновой концетрат проходит два этапа очистки, в результате которых из него дополнительно выделяют и убирают отвальные хвосты.
# 3. В конечном итоге получается финальный концентрат, содержащий в основном ценные металлы.
#
# Весь технологический процесс зависит от множества переменных, это может быть концентрация исходного сырья, размер гранул сырья, концентрация реагентов, скорость подачи воздуха, уровень воды во флотационной установке и другие. Попробуем с помощью машинного обучения научиться предсказывать эффективность восстановления золота.
#
# Для этой цели нам предоставлено три датасета, обучающий, тестовый и полный, содержащие информацию о параметрах процесса, как было перечислено выше это могут быть размеры гранул сырья, различные концентрации и прочее.
#
# Нам необходимо предсказать две величины:
# 1. Эффективнсоть обогащения чернового концентрата
# 2. Эффективность обогащения финального концентрата
#
# Эффективность обогащения расчитывается по следующей формуле:
# ![image.png](attachment:image.png)
#
# Для оценки моделей используются: sMAPE и total_sMAPE (учитывающий метрику модели чернового и финального концентрата) их формулы ниже
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# Порядок выполнения проекта:
# 1. Изучим и подготовим данные
# 2. Проанализируем параметры процесса
# 3. Обучим и протестируем модели

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Импорт библиотек:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.dummy import DummyRegressor
from lightgbm import LGBMRegressor

sns.set_style('ticks', {'axes.grid': 'True'})
sns.set_context('notebook')
pd.set_option('display.max_columns', 500)

# %%
SEED = 42

# %% [markdown]
# Нам предоставлено 3 датасета, обучающий, тестовый и полный, откроем их:

# %%
try:
    data_train = pd.read_csv('datasets/gold_recovery_train_new.csv')
    data_test = pd.read_csv('datasets/gold_recovery_test_new.csv')
    data_full = pd.read_csv('datasets/gold_recovery_full_new.csv')
except:
    data_train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
    data_test = pd.read_csv('/datasets/gold_recovery_test_new.csv')
    data_full = pd.read_csv('/datasets/gold_recovery_full_new.csv')

# %%
datas = {
    'train':data_train,
    'test':data_test,
    'full':data_full
}

# %% [markdown]
# Изучим, какую информацию содержат признаки, а так же общую информацию о датафреймах:

# %%
for data in datas:
    print('Датафрейм', data)
    display(datas[data].head(3))
    datas[data].info()
    print('-'*100)
# Out:
# Датафрейм train
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# 2                    42.657501              68.116445             10.507046
#
#    final.output.tail_pb  final.output.tail_sol  final.output.tail_au  \
# 0              0.895447              16.904297              2.143149
# ...

# %% [markdown]
# Итак, у нас есть 3 огромных датасета:
# * data_train - обучающая выборка, 14149 наблюдений, 87 признаков
# * data_test - тестовая выборка, 5290 наблюдений, 53 признака
# * data_full - полный датасет, 19439 наблюдений, 87 признаков
#
# Все признаки, кроме даты - числа с плавающей точкой. Они содержат различную информацию о техническом процессе, количество загруженного сырья, полученных концентратов, уровня жидкости/воздуха и т.д.
#
# Сами признаки расшифровываются следующим образом:
# **[этап].[тип_параметра].[название_параметра]**
#
# 1. **Этап процесса** - флотация, первичная, вторичная очистка и финальные характеристики
# * rougher - флотация
# * primary_cleaner - первичная очистка
# * secondary_cleaner - вторичная очистка
# * final - финальные характеристики
# 2. **Тип параметра** - параметры сырья, продукта, характеристики этапа и расчетные характеристики
# * input - параметры сырья, на входе в процесс
# * output - параметры продукта, на выходе из процесса
# * state - параметры, характеризующие состояние этапа
# * calculation - расчетные характеристики этапа
# 3. **Название параметра** - вариантов много, основные:
# * feed_ag/au/pb/sol/rate/size - подача сырья, (серебро, золото свинец), отношение, размер гранул
# * floatbank10_sulfate/xanthate - подача реагентов флотации
# * concentrate_ag/au/pb - концентрат продукта
# * tail_ag/au/pb - отвальные хвосты продукта
# * recovery - эффективность восстановления (расчетная характеристика)
# * floatbank8_a_air/a_level - параметры подачи воздуха
# * au_pb_ratio - отношение золота к свинцу
# И другие параметры, их можно расшифорвать пользуясь инструкцией выше
#
# В датасетах присутствуют пропуски, а так же необходимо привести дату к соответствующему виду:

# %%
data_train['date'] = pd.to_datetime(data_train['date'], format='%Y-%m-%d %H:%M:%S')
data_test['date'] = pd.to_datetime(data_test['date'], format='%Y-%m-%d %H:%M:%S')
data_full['date'] = pd.to_datetime(data_full['date'], format='%Y-%m-%d %H:%M:%S')

# %%
def nans_graph(df):
    nan_df = pd.DataFrame()
    nan_df['percent'] = (100*df.isna().sum()/len(df)).sort_values()
    nan_df['count'] = df.isna().sum().sort_values()
    nan_df = nan_df[nan_df['count'] > 0]
    nan_percent_max = nan_df['percent'].max()

   
    fig_height = int(len(nan_df)*0.2) + 3
    figsize=(8, fig_height)
    
    plt.figure(figsize=figsize)
    plt.grid(alpha=0.8)
    plt.xticks(range(0,110,2))
    plt.xlim(0, nan_percent_max + 5)
    plt.xlabel('% пропущенных значений')
    plt.ylim(-1, len(nan_df))
    
    xpos = nan_df['percent'] + nan_percent_max*0.02
    
    for x, y, txt in zip(xpos, nan_df.index, nan_df['count']):
        plt.text(x, y, f'{txt} шт.', verticalalignment='center')
        
    plt.hlines(y=nan_df.index, xmin = 0, xmax = nan_df['percent'], colors='r', alpha=0.5)
    plt.title(f'Количество пропусков в данных\nВсего записей: {len(df)}', size=14)
    plt.grid(linestyle='--', alpha=0.5)
    plt.tight_layout()

# %% [markdown]
# Пропуски в датасетах:

# %%
nans_graph(data_train)

# %%
nans_graph(data_test)

# %%
nans_graph(data_full)

# %% [markdown]
# Пропуски присутствуют во всех этапах, заполнять их будем с помощью KNNImputer на этапе машинного обучения.

# %% [markdown]
# ### Проверка эффективности обогащения

# %% [markdown]
# Проверим, что эффективность обогащения проверена правильно, вычислим ее на обучающей выборке по следующей формуле:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# где:
# * C — доля золота в концентрате после флотации/очистки. **Это признак - data_train['rougher.output.concentrate_au']**
# * F — доля золота в сырье до флотации (концентрате до очистки). **Это признак - data_train['rougher.input.feed_au']**
# * T — доля золота в отвальных хвостах после флотации/очистки. **Это признак - data_train['rougher.output.tail_au']**

# %%
def recovery(C,F,T):
    return 100*(C*(F-T))/(F*(C-T))

# %% [markdown]
# Признаки:

# %%
C = data_train['rougher.output.concentrate_au']
F = data_train['rougher.input.feed_au']
T = data_train['rougher.output.tail_au']

# %% [markdown]
# В датасете эффективность уже записана, она содержится в **data_train['rougher.output.recovery']**

# %%
recovery_check = recovery(C,F,T)
recovery_true = data_train['rougher.output.recovery']

# %% [markdown]
# Вычисляем MAE между существующими расчетами и по формуле:

# %%
mean_absolute_error(recovery_true, recovery_check)
# Out:
# 1.1131451184435918e-14

# %% [markdown]
# **Ошибка равна примерно 10^(-14), это означает, что в датасете эффективность рассчитана корректно.**

# %% [markdown]
# ### Различие тестовой и обучающей выборок

# %% [markdown]
# Изучим, какие признаки есть в обучающей выборке, но нет в тестовой:

# %%
set(data_train.columns) - set(data_test.columns)
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# Проверим, есть ли пересечения по дате проведения эксперимента в обучающей и тестовой выборке:

# %%
len(set(data_train['date']) - set(data_test['date']))
# Out:
# 14149

# %%
len(data_train)
# Out:
# 14149

# %% [markdown]
# Тестовая и обучающая выборки не имеют пересечений по дате эксперимента, обработка не требуется, модель будет обучаться и тестироваться на разных данных.
#
# Сами выборки имеют различие по содержащимся в них признакам, в тестовой выборке отсутствуют признаки:
# * .output - признаки, получающиеся на выходе из тех или иных процессов (очистки/флотации)
# * .calculation - расчетные признаки

# %% [markdown]
# Для удобства проиндексируем датасеты по дате:

# %%
data_train.index = data_train['date']
data_train.drop(columns=['date'], inplace=True)

data_test.index = data_test['date']
data_test.drop(columns=['date'], inplace=True)

data_full.index = data_full['date']
data_full.drop(columns=['date'], inplace=True)

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Концентрации металлов Au, Ag, Pb на различных этапах технологического процесса

# %%
process_dict = {'rougher.input.feed':'Флотация, вход',
                'rougher.output.concentrate':'Флотация, выход',
                'primary_cleaner.output.concentrate':'Очистка 1, выход',
                'final.output.concentrate':'Очистка 2, выход'
}

# %%
fig, axs = plt.subplots(1, len(process_dict), figsize=(16, 5), constrained_layout=True)
fig.suptitle('Изменение концентрации золота (Au) на различных этапах', fontsize=24)
for stage, ax in zip(process_dict.keys(), axs):
    ax.set_title(process_dict[stage])
    ax.set(ylabel=' ')
    cols = data_train.columns.str.contains(stage+'_au')
    sns.histplot(data_train.loc[:, cols].dropna(), ax=ax)

# %%
fig, axs = plt.subplots(1, len(process_dict), figsize=(16, 5), constrained_layout=True)
fig.suptitle('Изменение концентрации свинца (Pb) на различных этапах', fontsize=24)
for stage, ax in zip(process_dict.keys(), axs):
    ax.set_title(process_dict[stage])
    ax.set(ylabel=' ')
    cols = data_train.columns.str.contains(stage+'_pb')
    sns.histplot(data_train.loc[:, cols].dropna(), ax=ax)

# %%
fig, axs = plt.subplots(1, len(process_dict), figsize=(16, 5), constrained_layout=True)
fig.suptitle('Изменение концентрации серебра (Ag) на различных этапах', fontsize=24)
for stage, ax in zip(process_dict.keys(), axs):
    ax.set_title(process_dict[stage])
    ax.set(ylabel=' ')
    cols = data_train.columns.str.contains(stage+'_ag')
    sns.histplot(data_train.loc[:, cols].dropna(), ax=ax)

# %% [markdown]
# Концентрация золота быстро растет, от 7% в среднем, до 45% в среднем на финальной стадии процесса
#
# Концентрация свинца тоже растет, достигая примерно 10% на финальной стадии, это побочный продукт
#
# Содержание серебра падает, после последней очистки в среднем 5%, против 8-9% на старте

# %% [markdown]
# ### Распределение гранул сырья в обучающей и тестовой выборках

# %%
plt.figure(figsize=(10,5))
sns.histplot(data_train['rougher.input.feed_size'].dropna(), label='train', color='r', bins=200, stat='density')
sns.histplot(data_test['rougher.input.feed_size'].dropna(), label='test', color='b', bins=200, stat='density')
plt.title('Сравнение распределение размеров гранул сырья на обучающей и тестовой выборках')
plt.xlabel('Размеры гранул сырья')
plt.ylabel('Количество наблюдений')
plt.legend()
plt.xlim(0,150)
plt.show()

# %%
data_train['rougher.input.feed_size'].describe()
# Out:
# count    14005.000000
# mean        60.110518
# std         22.418485
# min          9.659576
# 25%         48.973027
# 50%         55.373885
# 75%         66.080172
# max        484.967466
# Name: rougher.input.feed_size, dtype: float64

# %%
data_test['rougher.input.feed_size'].describe()
# Out:
# count    5289.000000
# mean       55.951097
# std        19.081758
# min         0.046369
# 25%        43.906347
# 50%        50.841029
# 75%        62.431047
# max       392.494040
# Name: rougher.input.feed_size, dtype: float64

# %% [markdown]
# Размеры гранул отличаются, но не сильно, дополнительную обработку проводить не нужно

# %% [markdown]
# ### Суммарная концентрация всех веществ на разных стадиях

# %%
fig, axs = plt.subplots(1, 4, figsize=(16, 5))
for stage, ax in zip(process_dict.keys(), axs):
    ax.set_title(process_dict[stage])
    ax.set(ylabel=' ')
    total = data_full[stage+'_ag'] + data_full[stage+'_au'] + data_full[stage+'_pb'] + data_full[stage+'_sol']
    sns.histplot(total.dropna(), ax=ax, bins=200)

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Удаление аномальных значений, выделение обучающей и тестовой выборок

# %% [markdown]
# Удаление нулевых и очень маленьких значений:

# %%
metals = ['_au', '_pb', '_ag', '_sol']

# %%
for stage in process_dict.keys():
    for met in metals:  
        data_train.drop(data_train[data_train[stage+met] <= 1].index, inplace=True)

# %% [markdown]
# В обучающей выборке необходимо оставить только те признаки, которые есть в тесте, иначе не получится провести тестирование.

# %%
X_train = data_train[data_test.columns]

# %% [markdown]
# Эффективность обогащения чернового концентрата зависит только от переменных на входе во флотационную установку, а так же регуляции самой установки.
#
# Эффективность обогащения финального концентрата зависит от переменных на входе в устанвки очистки, а так же их регуляции
#
# Выделим эти признаки в разные обучающие выборки:

# %%
rougher_cols = X_train.columns.str.contains('rougher')
final_cols = X_train.columns.str.contains('cleaner')

# %%
X_train_rougher = X_train.loc[:, rougher_cols]
X_test_rougher = data_test.loc[:, rougher_cols]

X_train_cleaner = X_train.loc[:, final_cols]
X_test_cleaner = data_test.loc[:, final_cols]

# %% [markdown]
# Проверка:

# %%
set(X_test_rougher.columns) == set(X_train_rougher.columns)
# Out:
# True

# %%
set(X_test_cleaner.columns) == set(X_train_cleaner.columns)
# Out:
# True

# %% [markdown]
# Тестовая выборка:

# %%
y_train_rougher = data_train[['rougher.output.recovery']].values.ravel()
y_train_cleaner = data_train[['final.output.recovery']].values.ravel()

# %%
y_test_rougher = data_full.loc[X_test_rougher.index, 'rougher.output.recovery']
y_test_cleaner = data_full.loc[X_test_cleaner.index, 'final.output.recovery']

# %% [markdown]
# Проверка корректности разбиения:

# %%
print(X_train_rougher.shape, y_train_rougher.shape, X_train_cleaner.shape, y_train_cleaner.shape)
# Out:
# (13426, 22) (13426,) (13426, 30) (13426,)

# %%
print(X_test_rougher.shape, y_test_rougher.shape, X_test_cleaner.shape, y_test_cleaner.shape)
# Out:
# (5290, 22) (5290,) (5290, 30) (5290,)

# %% [markdown]
# ### Метрики качества моделей

# %% [markdown]
# Модели необходимо оценивать с помощью метрики sMAPE
# ![image.png](attachment:image.png)
#
# Ее функция:

# %%
def smape_score(y, y_pred):
    numerator = abs(y-y_pred)
    denominator = (abs(y)+abs(y_pred))/2
    
    smape = 100*np.mean(numerator/denominator)
    
    return smape

# %% [markdown]
# Необходимо, чтобы эта метрика была минимальной, для этого создадим оценщик с параметром greater_is_better=False

# %%
sMAPE = make_scorer(smape_score, greater_is_better=False)

# %% [markdown]
# Общая метрика по процессам флотации и очистки:
# ![image.png](attachment:image.png)

# %%
def total_smape_score(rougher_smape, final_smape):
    total_smape = 0.25*rougher_smape + 0.75*final_smape
    return total_smape

# %% [markdown]
# ### Обучение моделей

# %% [markdown]
# Попробуем 2 модели:
# 1. LightGBMRegressor
# 2. LinearRegression
#
# Для первой модели попробуем перебрать количество решающих деревьев, максимальную глубину дерева и скорость обучения. Для линейной регрессии нет гиперпараметров, которые можно перебирать

# %%
LGBMR = LGBMRegressor(n_jobs=-1, random_state=SEED)
LR = LinearRegression(n_jobs=-1)

# %% [markdown]
# Пропуски будем заполнять с помощью KNNImputer-а, он будет автоматически заполнять пропуски на основе похожих соседей. Данные приведем к одному масштабу с помощью StandardScaler.

# %%
scaler = StandardScaler()

steps = [
    ('imp', KNNImputer(missing_values=np.nan)),
    ('scaler', scaler),
    ('model', LGBMR)
]

pipe = Pipeline(steps)

# %%
params = [
    {
        'model': [LGBMR],
        'model__max_depth': np.arange(1,20,1),
        'model__n_estimators': [50, 100, 150, 200, 250, 500],
        'model__learning_rate': [0.001, 0.01, 0.1, 0.5]
    }, {
        'model': [LR]
    }
]

# %%
grid_rougher = GridSearchCV(pipe, param_grid=params, cv=5, scoring=sMAPE, n_jobs=-1)

# %%
# %%time
grid_rougher.fit(X_train_rougher, y_train_rougher)
print(grid_rougher.best_score_)
print(grid_rougher.best_estimator_)
# Out:
# /Users/lefantino/opt/anaconda3/envs/pet_projects_env/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# -5.874843330493664
# Pipeline(steps=[('imp', KNNImputer()), ('scaler', StandardScaler()),
#                 ('model',
#                  LGBMRegressor(learning_rate=0.01, max_depth=3,
#                                n_estimators=250, random_state=42))])
# CPU times: user 16.2 s, sys: 3.69 s, total: 19.9 s
# Wall time: 8min 5s

# %%
grid_cleaner = GridSearchCV(pipe, param_grid=params, cv=5, scoring=sMAPE, n_jobs=-1)

# %%
# %%time
grid_cleaner.fit(X_train_cleaner, y_train_cleaner)
print(grid_cleaner.best_score_)
print(grid_cleaner.best_estimator_)
# Out:
# -9.50377122211433
# Pipeline(steps=[('imp', KNNImputer()), ('scaler', StandardScaler()),
#                 ('model',
#                  LGBMRegressor(max_depth=1, n_estimators=50, random_state=42))])
# CPU times: user 12 s, sys: 1.67 s, total: 13.7 s
# Wall time: 9min

# %%
rougher_best_model = grid_rougher.best_estimator_
cleaner_best_model = grid_cleaner.best_estimator_

# %%
rougher_pred = rougher_best_model.predict(X_test_rougher)
cleaner_pred = cleaner_best_model.predict(X_test_cleaner)

# %%
sMAPE_rougher = smape_score(y_test_rougher, rougher_pred)
sMAPE_cleaner = smape_score(y_test_cleaner, cleaner_pred)

# %%
total_smape_score(sMAPE_rougher, sMAPE_cleaner)
# Out:
# 8.540352089100882

# %% [markdown]
# ### Сравнение с DummyRegressor

# %%
dummy_rougher = DummyRegressor(strategy='mean')
dummy_cleaner = DummyRegressor(strategy='mean')

dummy_rougher.fit(X_train_rougher, y_train_rougher)
dummy_cleaner.fit(X_train_cleaner, y_train_cleaner)

rougher_dummy_pred = dummy_rougher.predict(X_test_rougher)
cleaner_dummy_pred = dummy_cleaner.predict(X_test_cleaner)

# %%
sMAPE_rougher_dummy = smape_score(y_test_rougher, rougher_dummy_pred)
sMAPE_cleaner_dummy = smape_score(y_test_cleaner, cleaner_dummy_pred)

# %%
total_smape_score(sMAPE_rougher_dummy, sMAPE_cleaner_dummy)
# Out:
# 9.798045268911936

# %% [markdown]
# Наши модели получились значительно лучше константных, константная модель дает ошибку 19.43%, наши модели всего 8.54%

# %% [markdown]
# ## Вывод по проекту

# %% [markdown]
# В данном проекте нам необходимо было построить модели для прогнозирования эффективности обогащения чернового концентрата и финального концентрата. Данные для прогнозирования представлены 3 датасетами. В полном датасете 87 признаков, в тестовом - 52. Тренировочный набор данных включает 16860 объектов, тестовый - 5856 (деление примерно 75%-25%).
#
# В датафреймах нам встретилось большое количество пропусков в разных строках и признаках, а так же небольшое количество дубликатов, которые мы обработали сразу же. Для обработки пропусков мы решили использовать KNNImputer и заполнить их на этапе машинного обучения.
#
# На этапе исследования данных мы выяснили, что:
# 1. Концентрация золота растет от 7 до 45% в результате очистки
# 2. Концентрация серебра уменьшается почти до 5%
# 3. Концентрация свинца растет почти до 10% в результате очистки
#
# На этапе машинного обучения мы создали pipeline и провели поиск по сетке, стараясь выявить лучшую модель по метрике sMAPE. Мы использовали две модели: линейную регрессию и градиентный бустинг. При поиске по сетке мы перебирали различные параметры моделей
#
# В результате лучшими моделями оказались два градиентных бустинга с параметрами:

# %%
print(grid_rougher.best_estimator_)
# Out:
# Pipeline(steps=[('imp', KNNImputer()), ('scaler', StandardScaler()),
#                 ('model',
#                  LGBMRegressor(learning_rate=0.01, max_depth=3,
#                                n_estimators=250, random_state=42))])

# %%
print(grid_cleaner.best_estimator_)
# Out:
# Pipeline(steps=[('imp', KNNImputer()), ('scaler', StandardScaler()),
#                 ('model',
#                  LGBMRegressor(max_depth=1, n_estimators=50, random_state=42))])

# %% [markdown]
# Мы проверили модели на тестовой выборке и вычислили итоговую метрику total_sMAPE, получили результат 8.54. Так же мы сравнили наши модели с DummyRegressor, его результат составил 19.43%, что значительно хуже наших моделей.
